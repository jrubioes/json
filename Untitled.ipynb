# %%
import requests

headers = {"Authorization": "Bearer e94a7ad79bf3a5caaf73103bb391247a1fa9c895"}
url = 'https://api.merchantos.com/API/Account.json'

# %%
import requests
import json
code = input('code'),
url = "https://cloud.merchantos.com/oauth/access_token.php"

payload = {
    "client_id": "a8e3528e7db447c120a8a616b9378e70f5fcb82490a5d83f66e34378db2a4a2e"    ,
    "client_secret": "8ea90c0f25838b5f3ed4cccb701828a5e836ff42ebb368ef3b247e260d463afc" ,
    "code": code,
    "grant_type": "authorization_code"}

response = requests.request("POST", url, data=payload)
print(response.text)

with open("code.json","w") as out_file:
        out_string =""
        out_string += str(response.text)
        out_file.write(out_string)

print ("Leer archivos")
leer = json.loads(open('code.json').read())
print (code.access_token)
# Out:
# {"access_token":"c8c5179282c972b962223481f4a2356655ae8a0c","expires_in":821,"token_type":"bearer","scope":"employee:all","refresh_token":"5bbd7ff0b01b50537090b9bea3e4639ca7f21491"}
# Leer archivos
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c1e2df8c3edb> in <module>()
#      19
#      20 print ("Leer archivos")
# ---> 21 leer = json.loads(open('code.json').read(access_token))
#      22 print (leer)
#      23
#
# NameError: name 'access_token' is not defined

# %%
import requests
url4 = "https://api.merchantos.com/API/Account/131147/Sale.json?timeStamp=<,2018-01-31T00:00:00-0400"
url1 = "https://api.merchantos.com/API/Account/131147/Customer.json"
url3 = "https://api.merchantos.com/API/Account/131147/RegisterCount/2"
payload4 = {              
}


headers = {"Authorization": "Bearer c8c5179282c972b962223481f4a2356655ae8a0c"}

response4 = requests.request("GET", url4, data=payload4, headers=headers)
response3 = requests.request("GET", url3, data=payload4, headers=headers)
response1 = requests.request("GET", url1, data=payload4, headers=headers)


print(response3.text)
with open("rodri_ventas.txt","w") as out_file:
        out_string =""
        out_string += str(response4.text)
        out_file.write(out_string)
with open("rodri_clientes.txt","w") as out_file:
        out_string =""
        out_string += str(response1.text)
        out_file.write(out_string)

# %%
with open("sales.txt","w") as out_file:
        out_string =""
        out_string += str(response4.text)
        out_file.write(out_string)
# Out:
# {"@attributes":{"count":"20","offset":"0","limit":"100"},"Sale":[{"saleID":"1","timeStamp":"2018-01-04T10:57:24+00:00","discountPercent":"0","completed":"false","archived":"false","voided":"false","enablePromotions":"true","isTaxInclusive":"false","createTime":"2018-01-04T10:57:24+00:00","updateTime":"2018-01-04T10:57:24+00:00","referenceNumber":"","referenceNumberSource":"","tax1Rate":"0.0825","tax2Rate":"0","change":"0","receiptPreference":"printed","displayableSubtotal":"0","ticketNumber":"220000000001","calcDiscount":"0","calcTotal":"0","calcSubtotal":"0","calcTaxable":"0","calcNonTaxable":"0","calcAvgCost":"0","calcFIFOCost":"0","calcTax1":"0","calcTax2":"0","calcPayments":"0","total":"0","totalDue":"0","displayableTotal":"0","balance":"0","customerID":"0","discountID":"0","employeeID":"1","quoteID":"0","registerID":"1","shipToID":"0","shopID":"1","taxCategoryID":"1","taxTotal":"0"},{"saleID":"2","timeStamp":"2018-01-04T10:57:24+00:00","discountPercent":"0","completed":"false","
# ...

# %%
i = 0
leer = json.loads(open('code.json').read())
print (leer)
# Out:
# Leer archivos
# {'access_token': 'c8c5179282c972b962223481f4a2356655ae8a0c', 'expires_in': 821, 'token_type': 'bearer', 'scope': 'employee:all', 'refresh_token': '5bbd7ff0b01b50537090b9bea3e4639ca7f21491'}
